# %% [markdown]
# # Python Basics
# ## Week three - Thursday

# %%
# Strings

name = "John Doe"
print(type(name))

print(name[5:8])
print(len(name))
print(name[-3])
print(name[:])
print(name[-3:])
# Out:
# <class 'str'>
# Doe
# 8
# D
# John Doe
# Doe

# %%
first = "john"
last = "doe"

alt_name = first + " " + last

print(alt_name)

pi = 3.14159

pi_with_desc = "The value of pi is " + str(pi)

print(pi_with_desc)

a = "abc"
b = "def"

c = b - a
# Out:
# john doe
# The value of pi is 3.14159
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-12ef1aba19f4> in <module>()
#      15 b = "def"
#      16
# ---> 17 c = b - a
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a = True

print(a)
print(type(a))

b = 1 < 2
c = 0 > 1

d = b and c
e = b or c
f = b and not c
g = not b or not c
h = not (b and c)
print("b and c is " + str(d))
print("b or c is " + str(e))
print("b and not c is "+ str(f))
print("not b or not c is", g)
print("not (b and c)", h)
# Out:
# True
# <class 'bool'>
# b and c is False
# b or c is True
# b and not c is True
# not b or not c is True
# not (b and c) True

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib notebook

# %%
array_1d = np.array([0, 1.8, 4.3, 9, 14.9, 28, 50])
type(array_1d)
len(array_1d)
array_1d.ndim
array_1d.dtype
plt.plot(array_1d)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(array_1d, '-ro')
plt.show()

# %%
f = 32
c = (5/9)*(f-32)
print(c)
# Out:
# 0.0

# %% [markdown]
# This function does cool things

# %%
def convert(f):
    c = (5/9)*(f-32) # convert f to c
    return c
converted_temp = convert(array_1d)
print(converted_temp)
# Out:
# [-17.77777778 -16.77777778 -15.38888889 -12.77777778  -9.5         -2.22222222
#   10.        ]

# %%
temps = np.linspace(0,1000,10)
print(convert(temps))
# Out:
# [ -17.77777778   43.95061728  105.67901235  167.40740741  229.13580247
#   290.86419753  352.59259259  414.32098765  476.04938272  537.77777778]

# %%
n = 10
if (n > 10):
    print("hi")
elif (n == 10):
    print("exact")
else: # n < 10
    print("too bad")
# Out:
# exact

# %%
index = 0
while (index < len(temps)):
    print(temps[index])
    index = index + 1
# Out:
# 0.0
# 111.111111111
# 222.222222222
# 333.333333333
# 444.444444444
# 555.555555556
# 666.666666667
# 777.777777778
# 888.888888889
# 1000.0

# %%
def columnPrint(array):
    for element in array:
        print(element)
    return

# %%
columnPrint(temps)
# Out:
# 0.0
# 111.111111111
# 222.222222222
# 333.333333333
# 444.444444444
# 555.555555556
# 666.666666667
# 777.777777778
# 888.888888889
# 1000.0

# %%
print(a % b)
# Out:
# 3
